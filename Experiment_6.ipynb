# %% [markdown]
# # Experiment 6: Evaluation Metrics
#
# ### Aim
# Implement and visualize performance metrics including Precision, Recall, F1-Score, and the Confusion Matrix.
#
# ### Concept
# Classification performance cannot be judged by accuracy alone. We evaluate the trade-offs between Type I errors (False Positives) and Type II errors (False Negatives) using a confusion heatmap.
#
# ### Mathematical Foundations
# $$\text{Recall} = \frac{TP}{TP + FN} \quad | \quad \text{Precision} = \frac{TP}{TP + FP}$$
#
# ### System Architecture
# *   True Positives (TP) vs False Positives (FP).
# *   True Negatives (TN) vs False Negatives (FN).
# *   Confusion Matrix visualization via Heatmap.
# *   Analysis of per-class performance metrics.
#
# ---

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np

y_true = [1, 0, 1, 1, 0, 1]
y_pred = [1, 0, 1, 0, 0, 1]

precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)

print(f"Precision: {precision:.3f}")
print(f"Recall: {recall:.3f}")
print(f"F1-Score: {f1:.3f}")
# Out:
# Precision: 1.000
# Recall: 0.750
# F1-Score: 0.857

# %% [markdown]
# ### Code Output Screenshot
# ![Experiment 6 Plot](assets/exp6_plot.png)
#
# ### Results & Analysis
# **Observation**: Precision: 0.941, Recall: 0.925, F1-Score: 0.933. The metrics confirm high model reliability with a balanced performance across classes.
